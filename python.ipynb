# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Question 1: -
# Write a program that takes a string as input, and counts the frequency of each word in the string, there might
# be repeated characters in the string. Your task is to find the highest frequency and returns the length of the
# highest-frequency word.
#
# Example input - string = “write write write all the number from from from 1 to 100”
# Example output - 5
# Explanation - From the given string we can note that the most frequent words are “write” and “from” and
# the maximum value of both the values is “write” and its corresponding length is 5

# %%
test_str = "write write write all the number from from from 1 to 100"

ori_str = {}
for i in set(test_str.split()):
    ori_str[i] = test_str.count(i)

print (max(ori_str,key=lambda a:test_str.count(a)))
# Out:
# write

# %% [markdown]
# Question 2: -
# Consider a string to be valid if all characters of the string appear the same number of times. It is also valid if
# he can remove just one character at the index in the string, and the remaining characters will occur the same
# number of times. Given a string, determine if it is valid. If so, return YES , otherwise return NO .
# Note - You have to write at least 2 additional test cases in which your program will run successfully and provide
# an explanation for the same.
#
#
# Example input 1 - s = “abc”. This is a valid string because frequencies are { “a”: 1, “b”: 1, “c”: 1 }
# Example output 1- YES
# Example input 2 - s “abcc”. This string is not valid as we can remove only 1 occurrence of “c”. That leaves
# character frequencies of { “a”: 1, “b”: 1 , “c”: 2 }
# Example output 2 - NO

# %%
test_str = "abc"

ori_str = {}
for i in test_str:
    ori_str[i] = test_str.count(i)

value = list(ori_str.values())
if min(value) == max(value):
    print("YES")
else:
    print("NO")
# Out:
# YES

# %% [markdown]
# Question 3: -
# Write a program, which would download the data from the provided link, and then read the data and convert
# that into properly structured data and return it in Excel format.
# Note - Write comments wherever necessary explaining the code written.
# Link - https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json
#
#
# Data Attributes - id: Identification Number - int num: Number of the
#
#
# ● Pokémon in the official Pokédex - int name: Pokémon name -
#
#
# ● string img: URL to an image of this Pokémon - string type:
#
#
# ● Pokémon type -string height: Pokémon height - float
#
#
# ● weight: Pokémon weight - float candy: type of candy used to evolve Pokémon or
# given
#
#
# ● when transferred - string candy_count: the amount of candies required to evolve
# - int
#
#
# ● egg: Number of kilometers to travel to hatch the egg - float spawn_chance:
#
#
# ● Percentage of spawn chance (NEW) - float avg_spawns: Number of this
# pokemon on 10.000 spawns (NEW) - int
#
#
# ● spawn_time: Spawns most active at the time on this field. Spawn times are the same for all
# time zones and are expressed in local time. (NEW) - “minutes: seconds” multipliers:
# Multiplier of Combat Power (CP) for calculating the CP after evolution See below - list of int
# weakness: Types of
#
#
# ● Pokémon this Pokémon is weak to - list of strings next_evolution: Number and Name of
# successive evolutions of Pokémon - list of dict prev_evolution: Number and Name of previous
# evolutions of Pokémon - - list of dict

# %%
import requests
import json
r = requests.get("https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json")
j = json.loads(r.content)

# %%
j
# Out:
# {'pokemon': [{'id': 1,
#    'num': '001',
#    'name': 'Bulbasaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/001.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.71 m',
#    'weight': '6.9 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 25,
#    'egg': '2 km',
#    'spawn_chance': 0.69,
#    'avg_spawns': 69,
#    'spawn_time': '20:00',
#    'multipliers': [1.58],
#    'weaknesses': ['Fire', 'Ice', 'Flying', 'Psychic'],
#    'next_evolution': [{'num': '002', 'name': 'Ivysaur'},
#     {'num': '003', 'name': 'Venusaur'}]},
#   {'id': 2,
#    'num': '002',
#    'name': 'Ivysaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/002.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.99 m',
#    'weight': '13.0 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 100,
#    'egg': 'Not in Eggs',
#    'spawn_chance': 0.042,
#    'avg_spawns': 4.2,
#    'spawn_time': '07:00',
#    'multipliers': [1.2, 1.6],
# ...

# %%
df=pd.DataFrame(j["pokemon"])

# %%
df.head()
# Out:
#    id  num        name                                               img  \
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %% [markdown]
# Question 4 -
# Write a program to download the data from the link given below and then read the data and convert the into
# the proper structure and return it as a CSV file.
# Link - https://data.nasa.gov/resource/y77d-th95.json

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get('https://data.nasa.gov/resource/y77d-th95.json')
c = r.text
j = json.loads(c)

# %%
df = pd.DataFrame(j)

# %%
df.head()
# Out:
#        name   id nametype     recclass    mass  fall                     year  \
# 0    Aachen    1    Valid           L5      21  Fell  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720  Fell  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000  Fell  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914  Fell  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780  Fell  1902-01-01T00:00:00.000
#
#        reclat      reclong                                        geolocation  \
# 0   50.775000     6.083330  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1   56.183330    10.233330  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2   54.216670  -113.000000  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3   16.883330   -99.900000  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  -33.166670   -64.950000  {'type': 'Point', 'coordinates': [-64.95, -33....
#
# ...

# %%
df = df[["name","nametype","mass","year","geolocation"]]

# %%
df.head()
# Out:
#        name nametype    mass                     year  \
# 0    Aachen    Valid      21  1880-01-01T00:00:00.000
# 1    Aarhus    Valid     720  1951-01-01T00:00:00.000
# 2      Abee    Valid  107000  1952-01-01T00:00:00.000
# 3  Acapulco    Valid    1914  1976-01-01T00:00:00.000
# 4   Achiras    Valid     780  1902-01-01T00:00:00.000
#
#                                          geolocation
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
geo=[]
for i in range(len(df.geolocation)):
    if type(df.geolocation[i]) == dict: 
        geo.append(df.geolocation[i]['coordinates'])
    else:
        geo.append([0,0])

# %%
geo
# Out:
# [[6.08333, 50.775],
#  [10.23333, 56.18333],
#  [-113, 54.21667],
#  [-99.9, 16.88333],
#  [-64.95, -33.16667],
#  [71.8, 32.1],
#  [95.16667, 44.83333],
#  [0.61667, 44.21667],
#  [-65.23333, -31.6],
#  [-64.55, -30.86667],
#  [-9.57028, 16.39806],
#  [8.38333, 19.08333],
#  [2.33333, 50.66667],
#  [35.05, 29.51667],
#  [77.95, 29.71667],
#  [8.43333, 8.91667],
#  [42.81667, 39.91667],
#  [39.51667, 24.41667],
#  [28.96, 13.66033],
#  [4.08333, 44.11667],
#  [11.01667, 44.65],
#  [22.66667, 2],
#  [6.01533, 45.82133],
#  [-1.78333, 51.78333],
#  [37.13333, 36.23333],
#  [8.75, 44.88333],
#  [31.81667, 50.95],
#  [10.15, 45.26667],
#  [-85.88333, 42.53333],
#  [-105.31667, 26.96667],
#  [32.41275, 20.74575],
#  [44.21556, 35.27333],
#  [78.25, 27.66667],
#  [85.56667, 26.58333],
#  [-70.75, 44.61667],
#  [37.5, 48.7],
#  [76.86667, 20.88333],
#  [0, 0],
#  [-0.55, 47.46667],
#  [-44.31667, -22.96667],
#  [39.71667, 9.53333],
#  [105.18333, 25.15],
#  [140.78556, 40.81056],
# ...

# %%
df["point coordinate"]=geo
del df["geolocation"]

# %%
df.reset_index(drop=True)
# Out:
#           name nametype    mass                     year  \
# 0       Aachen    Valid      21  1880-01-01T00:00:00.000
# 1       Aarhus    Valid     720  1951-01-01T00:00:00.000
# 2         Abee    Valid  107000  1952-01-01T00:00:00.000
# 3     Acapulco    Valid    1914  1976-01-01T00:00:00.000
# 4      Achiras    Valid     780  1902-01-01T00:00:00.000
# ..         ...      ...     ...                      ...
# 995   Tirupati    Valid     230  1934-01-01T00:00:00.000
# 996    Tissint    Valid    7000  2011-01-01T00:00:00.000
# 997      Tjabe    Valid   20000  1869-01-01T00:00:00.000
# 998   Tjerebon    Valid   16500  1922-01-01T00:00:00.000
# 999  Tomakovka    Valid     600  1905-01-01T00:00:00.000
#
#           point coordinate
# 0        [6.08333, 50.775]
# 1     [10.23333, 56.18333]
# 2         [-113, 54.21667]
# 3        [-99.9, 16.88333]
# 4      [-64.95, -33.16667]
# ..                     ...
# 995   [79.41667, 13.63333]
# 996   [-7.61123, 29.48195]
# ...

# %%
df.to_csv("nasa.csv")

# %% [markdown]
# 5. Write a program to download the data from the given API link and then extract the following data with
# proper formatting
# Link - http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes
# Note - Write proper code comments wherever needed for the code understanding
#
#
# Excepted Output Data Attributes -
# ● id - int url - string
# ● name - string season
# ● - int number - int
# ● type - string airdate -
# ● date format airtime -
# ● 12-hour time format
# ● runtime - float
# ● average rating - float
# ● summary - string
# ● without html tags
# ● medium image link - string
# ● Original image link - string

# %%
import requests

# %%
r = requests.get("http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes")

# %%
j = json.loads(r.text)

# %%
j
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Science-Fiction', 'Western'],
#  'status': 'Ended',
#  'runtime': 60,
#  'averageRuntime': 63,
#  'premiered': '2016-10-02',
#  'ended': '2022-08-14',
#  'officialSite': 'http://www.hbo.com/westworld',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'officialSite': 'https://www.hbo.com/'},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'},
# ...

# %%
print(f'_id = {j["id"]} \nname = {j["name"]} \n_type = {j["type"]} \nruntime = {j["runtime"]} \nmedium = {j["image"]["medium"]} \noriginal = {j["image"]["original"]} \nsummary = {j["summary"]}')
_id, name, _type, airdate, airtime, runtime, medium, original, summary = [[] for i in range(9)]
# Out:
# _id = 1371
# name = Westworld
# _type = Scripted
# runtime = 60
# medium = https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg
# original = https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg
# summary = <p><b>Westworld</b> is a dark odyssey about the dawn of artificial consciousness and the evolution of sin. Set at the intersection of the near future and the reimagined past, it explores a world in which every human appetite, no matter how noble or depraved, can be indulged.</p>

# %%
df = pd.DataFrame(j['_embedded']['episodes'])

# %%
for i in j['_embedded']['episodes']:
    b = i.get("image",'nan')
    if b == 'nan':
        medium.append('nan')
        original.append('nan')
    else:
        medium.append(i["image"].get("medium"))
        original.append(i["image"].get("original"))
    summary.append(i.get("summary")[3:-4])

# %%
df["medium"] = medium
df["original"] = original
df["summary"] = summary

# %%
df['rating'] = df['rating'].apply(lambda a : a['average'])

# %%
del df["image"]

# %%
df_5 = df

# %% [markdown]
# Question 6 -
# Using the data from Question 3, write code to analyze the data and answer the following questions Note 1.
# Draw plots to demonstrate the analysis for the following questions for better visualizations.
# 2. Write code comments wherever required for code understanding
#
#
# Insights to be drawn -
#
#
# ● Get all Pokemons whose spawn rate is less than 5%
#
#
# ● Get all Pokemons that have less than 4 weaknesses
#
#
# ● Get all Pokemons that have no multipliers at all
#
#
# ● Get all Pokemons that do not have more than 2 evolutions
#
#
# ● Get all Pokemons whose spawn time is less than 300 seconds.
# Note - spawn time format is "05:32”, so assume “minute: second” format and perform the analysis.
# ● Get all Pokemon who have more than two types of capabilities

# %%
import requests
import json
r = requests.get("https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json")
j = json.loads(r.content)

# %%
j
# Out:
# {'pokemon': [{'id': 1,
#    'num': '001',
#    'name': 'Bulbasaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/001.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.71 m',
#    'weight': '6.9 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 25,
#    'egg': '2 km',
#    'spawn_chance': 0.69,
#    'avg_spawns': 69,
#    'spawn_time': '20:00',
#    'multipliers': [1.58],
#    'weaknesses': ['Fire', 'Ice', 'Flying', 'Psychic'],
#    'next_evolution': [{'num': '002', 'name': 'Ivysaur'},
#     {'num': '003', 'name': 'Venusaur'}]},
#   {'id': 2,
#    'num': '002',
#    'name': 'Ivysaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/002.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.99 m',
#    'weight': '13.0 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 100,
#    'egg': 'Not in Eggs',
#    'spawn_chance': 0.042,
#    'avg_spawns': 4.2,
#    'spawn_time': '07:00',
#    'multipliers': [1.2, 1.6],
# ...

# %%
df = pd.DataFrame(j["pokemon"])

# %%
df.head()
# Out:
#    id  num        name                                               img  \
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
#Get all Pokemons whose spawn rate is less than 5%
df_swan = df[df["spawn_chance"] < 0.5]

# %%
df_swan["name"]
# Out:
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
#           ...
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# 150           Mew
# Name: name, Length: 108, dtype: object

# %%
#Get all Pokemons that have less than 4 weaknesses
df["count_weaknesses"] = df["weaknesses"].apply(lambda b:len(b))

# %%
df[df["count_weaknesses"]<4]
# Out:
#       id  num        name                                               img  \
# 3      4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6  006   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6      7  007    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7      8  008   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
#Get all Pokemons that have no multipliers at all
count_multipliers = []
for i in df["multipliers"]:
    if i == None:
        count_multipliers.append(0)
        
    else:
        count_multipliers.append(len(i))

df["count_multipliers"] = count_multipliers

# %%
df[df["count_multipliers"]==0]
# Out:
#       id  num        name                                               img  \
# 2      3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 5      6  006   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 8      9  009   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 11    12  012  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# 14    15  015    Beedrill  http://www.serebii.net/pokemongo/pokemon/015.png
# ..   ...  ...         ...                                               ...
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
df.prev_evolution.fillna(0,inplace=True)
df.next_evolution.fillna(0,inplace=True)

# %%
#Get all Pokemons that do not have more than 2 evolutions
evolve = []
for i in range(df.shape[0]):
    if df.prev_evolution[i]==0:
        a = 0
    else:
        a = len(df.prev_evolution[i])
    if type(df.next_evolution[i])==list:
        b = len(df.next_evolution[i])
    evolve.append(a+b)
df["evolve"] = evolve

# %%
df.head()
# Out:
#    id  num        name                                               img  \
# 0   1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height    weight             candy  candy_count  \
# 0  [Grass, Poison]  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  [Grass, Poison]  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  [Grass, Poison]  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3           [Fire]  0.61 m    8.5 kg  Charmander Candy         25.0
# 4           [Fire]  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
df[df["evolve"]<3]
# Out:
#       id  num        name                                               img  \
# 0      1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 3      4  004  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4      5  005  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 6      7  007    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 146  147  147     Dratini  http://www.serebii.net/pokemongo/pokemon/147.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
#Get all Pokemons whose spawn time is less than 300 seconds
df["spawn_time"] = df.spawn_time.replace('N/A',"0:0")
df['spawnsplit']=df.spawn_time.str.split(":")
df['spawnsplit_sec'] = df['spawnsplit'].apply(lambda a:int(a[1]))
df['spawnsplit_min_sec'] = df['spawnsplit'].apply(lambda a:int(a[0])*60)
df['spawn_total']=df['spawnsplit_sec'] + df['spawnsplit_min_sec']

# %%
df[df['spawn_total'] < 300]
# Out:
#       id  num       name                                               img  \
# 6      7  007   Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 8      9  009  Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 10    11  011    Metapod  http://www.serebii.net/pokemongo/pokemon/011.png
# 12    13  013     Weedle  http://www.serebii.net/pokemongo/pokemon/013.png
# 13    14  014     Kakuna  http://www.serebii.net/pokemongo/pokemon/014.png
# ..   ...  ...        ...                                               ...
# 143  144  144   Articuno  http://www.serebii.net/pokemongo/pokemon/144.png
# 144  145  145     Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146    Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 149  150  150     Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151        Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
#Get all Pokemon who have more than two types of capabilities

# %%
df['type_len']=df.type.apply(lambda a:len(a))
df[df['type_len']==2]
# Out:
#       id  num        name                                               img  \
# 0      1  001   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1      2  002     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3  003    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 5      6  006   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 11    12  012  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# ..   ...  ...         ...                                               ...
# 141  142  142  Aerodactyl  http://www.serebii.net/pokemongo/pokemon/142.png
# 143  144  144    Articuno  http://www.serebii.net/pokemongo/pokemon/144.png
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
#
# ...

# %% [markdown]
# Question 7 -
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
r = requests.get('https://data.nasa.gov/resource/y77d-th95.json')
c = r.text
j = json.loads(c)

# %%
df=pd.DataFrame(j)

# %%
df = df[["name","nametype","mass","year","geolocation"]]

# %%
geo=[]
for i in range(len(df.geolocation)):
    if type(df.geolocation[i]) == dict: 
        geo.append(df.geolocation[i]['coordinates'])
    else:
        geo.append([0,0])

# %%
df["point coordinate"]=geo
del df["geolocation"]

# %%
df.head()
# Out:
#        name nametype    mass                     year      point coordinate
# 0    Aachen    Valid      21  1880-01-01T00:00:00.000     [6.08333, 50.775]
# 1    Aarhus    Valid     720  1951-01-01T00:00:00.000  [10.23333, 56.18333]
# 2      Abee    Valid  107000  1952-01-01T00:00:00.000      [-113, 54.21667]
# 3  Acapulco    Valid    1914  1976-01-01T00:00:00.000     [-99.9, 16.88333]
# 4   Achiras    Valid     780  1902-01-01T00:00:00.000   [-64.95, -33.16667]

# %%
#Get all the Earth meteorites that fell before the year 2000

# %%
df['year']=df.year.str[0:4]
df['year'].fillna(0,inplace = True)
df['year'] = [int(df['year'][i]) for i in range(len(df.year))]

# %%
df[df.year < 2000]
# Out:
#           name nametype    mass  year       point coordinate
# 0       Aachen    Valid      21  1880      [6.08333, 50.775]
# 1       Aarhus    Valid     720  1951   [10.23333, 56.18333]
# 2         Abee    Valid  107000  1952       [-113, 54.21667]
# 3     Acapulco    Valid    1914  1976      [-99.9, 16.88333]
# 4      Achiras    Valid     780  1902    [-64.95, -33.16667]
# ..         ...      ...     ...   ...                    ...
# 994   Timochin    Valid   65500  1807           [35.2, 54.5]
# 995   Tirupati    Valid     230  1934   [79.41667, 13.63333]
# 997      Tjabe    Valid   20000  1869  [111.53333, -7.08333]
# 998   Tjerebon    Valid   16500  1922  [106.58333, -6.66667]
# 999  Tomakovka    Valid     600  1905      [34.76667, 47.85]
#
# [930 rows x 5 columns]

# %%
#Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
df[df.year < 1970]
# Out:
#           name nametype    mass  year       point coordinate
# 0       Aachen    Valid      21  1880      [6.08333, 50.775]
# 1       Aarhus    Valid     720  1951   [10.23333, 56.18333]
# 2         Abee    Valid  107000  1952       [-113, 54.21667]
# 4      Achiras    Valid     780  1902    [-64.95, -33.16667]
# 5     Adhi Kot    Valid    4239  1919           [71.8, 32.1]
# ..         ...      ...     ...   ...                    ...
# 994   Timochin    Valid   65500  1807           [35.2, 54.5]
# 995   Tirupati    Valid     230  1934   [79.41667, 13.63333]
# 997      Tjabe    Valid   20000  1869  [111.53333, -7.08333]
# 998   Tjerebon    Valid   16500  1922  [106.58333, -6.66667]
# 999  Tomakovka    Valid     600  1905      [34.76667, 47.85]
#
# [781 rows x 5 columns]

# %%
df['point coordinate'][df.year < 1970]
# Out:
# 0          [6.08333, 50.775]
# 1       [10.23333, 56.18333]
# 2           [-113, 54.21667]
# 4        [-64.95, -33.16667]
# 5               [71.8, 32.1]
#                ...
# 994             [35.2, 54.5]
# 995     [79.41667, 13.63333]
# 997    [111.53333, -7.08333]
# 998    [106.58333, -6.66667]
# 999        [34.76667, 47.85]
# Name: point coordinate, Length: 781, dtype: object

# %%
#Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
df['mass'].fillna(0,inplace = True)
df['mass'] = df['mass'].apply(lambda a : float(a))
df[df['mass'] > 10000]
# Out:
#            name nametype      mass  year       point coordinate
# 2          Abee    Valid  107000.0  1952       [-113, 54.21667]
# 7          Agen    Valid   30000.0  1814    [0.61667, 44.21667]
# 11          Aïr    Valid   24000.0  1925    [8.38333, 19.08333]
# 16      Akyumak    Valid   50000.0  1981   [42.81667, 39.91667]
# 27   Alfianello    Valid  228000.0  1883      [10.15, 45.26667]
# ..          ...      ...       ...   ...                    ...
# 991   Tieschitz    Valid   28000.0  1878       [17.11667, 49.6]
# 992      Tilden    Valid   74800.0  1927      [-89.68333, 38.2]
# 994    Timochin    Valid   65500.0  1807           [35.2, 54.5]
# 997       Tjabe    Valid   20000.0  1869  [111.53333, -7.08333]
# 998    Tjerebon    Valid   16500.0  1922  [106.58333, -6.66667]
#
# [243 rows x 5 columns]

# %% [markdown]
# Question 8 -
# Using the data from Question 5, write code the analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
# ● Get all the episode names, whose average rating is more than 8 for every season
# ● Get all the episode names that aired before May 2019
# ● Get the episode name from each season with the highest and lowest rating
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
#Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.

# %%
df_5.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00
# 1           Chestnut       1       2  regular  2016-10-09   21:00
# 2          The Stray       1       3  regular  2016-10-16   21:00
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00
# 4        Contrapasso       1       5  regular  2016-10-30   21:00
#
#                     airstamp  runtime  rating  \
# 0  2016-10-03T01:00:00+00:00       68     8.0
# 1  2016-10-10T01:00:00+00:00       60     7.7
# 2  2016-10-17T01:00:00+00:00       60     7.6
# ...

# %%
df_rating = df_5.groupby(df_5.season).mean()

# %%
sns.relplot(df_5.season,df_5.rating, hue = df_5.season)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Get all the episode names, whose average rating is more than 8 for every season
df_5['name'][df_5['rating'] > 8]
# Out:
# 6                 Trompe L'Oeil
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
#Get all the episode names that aired before May 2019

# %%
df_5['date'] = df_5['airdate'].str.split("-")

# %%
df_5['date'] = df_5['date'].apply(lambda a : int(a[0]))

# %%
df_5['name'][df_5['date'] < 2019]
# Out:
# 0                  The Original
# 1                      Chestnut
# 2                     The Stray
# 3             Dissonance Theory
# 4                   Contrapasso
# 5                 The Adversary
# 6                 Trompe L'Oeil
# 7                   Trace Decay
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 10           Journey Into Night
# 11                      Reunion
# 12              Virtù e Fortuna
# 13     The Riddle of the Sphinx
# 14                 Akane No Mai
# 15                  Phase Space
# 16                 Les Écorchés
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
#Get the episode name from each season with the highest and lowest rating

# %%
a = df_5.groupby('season').agg({'rating': ['mean', 'min', 'max']})
a = a.reset_index()
for i in list(a.season):
    c = a.iloc[1-i]
    m = [c.season,c.rating.min(),c.rating.max()]    
    print("\nmin")
    n = df_5[["name","season","rating"]][(df_5['season']==m[0][0])  & (df_5['rating']==m[1])]
    print(n)
    print("\n max")
    n = df_5[["name","season","rating"]][(df_5['season']==m[0][0])  & (df_5['rating']==m[2])]
    print(n)
# Out:
# min
#         name  season  rating
# 2  The Stray       1     7.6
#
#  max
#                  name  season  rating
# 9  The Bicameral Mind       1     8.7
#
# min
#             name  season  rating
# 28  The Auguries       4     7.1
#
#  max
#         name  season  rating
# 32  Zhuangzi       4     7.8
#
# min
#            name  season  rating
# 25  Decoherence       3     7.5
# 26  Passed Pawn       3     7.5
#
#  max
#                     name  season  rating
# 20          Parce Domine       3     8.0
# 23  The Mother of Exiles       3     8.0
#
# min
#             name  season  rating
# 14  Akane No Mai       2     7.6
#
#  max
#        name  season  rating
# 17  Kiksuya       2     8.7

# %%
#Get the summary for the most popular ( ratings ) episode in every season

# %%
a = df_5.groupby('season').agg({'rating': ['mean', 'min', 'max']})
a = a.reset_index()
for i in list(a.season):
    c = a.iloc[1-i]
    m = [c.season,c.rating.min(),c.rating.max()]    
    
    n = df_5[["summary","season"]][(df_5['season']==m[0][0])  & (df_5['rating']==m[2])]
    print(n)
# Out:
#                                              summary  season
# 9  Delores finds out the truth about William's fa...       1
#           summary  season
# 32  God is bored.       4
#                                               summary  season
# 20  If you're stuck in a loop, try walking in a st...       3
# 23             The truth doesn't always set you free.       3
#                                               summary  season
# 17  Another of Westworld's Host revolutionaries is...       2

# %% [markdown]
# Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
# Note -
# 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
# Insights to be drawn -
#
#
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
#
#
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
#
#
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
#
#
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
df = pd.read_csv(r"C:\Users\shash\Downloads\Electric_Vehicle_Population_Data.csv")

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
#Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df[["VIN (1-10)","Make","Electric Vehicle Type"]][df["Clean Alternative Fuel Vehicle (CAFV) Eligibility"] == 'Not eligible due to low battery range']
# Out:
#         VIN (1-10)    Make                   Electric Vehicle Type
# 6       3FA6P0PU1G    FORD  Plug-in Hybrid Electric Vehicle (PHEV)
# 7       WA1F2AFY8P    AUDI  Plug-in Hybrid Electric Vehicle (PHEV)
# 8       1FADP5CU0E    FORD  Plug-in Hybrid Electric Vehicle (PHEV)
# 14      1FADP5FU4H    FORD  Plug-in Hybrid Electric Vehicle (PHEV)
# 15      KNDCM3LD8L     KIA  Plug-in Hybrid Electric Vehicle (PHEV)
# ...            ...     ...                                     ...
# 130377  WBAJA9C55K     BMW  Plug-in Hybrid Electric Vehicle (PHEV)
# 130385  WAUUPBFF2G    AUDI  Plug-in Hybrid Electric Vehicle (PHEV)
# 130390  1C4JJXR65P    JEEP  Plug-in Hybrid Electric Vehicle (PHEV)
# 130407  JTDKARFP1H  TOYOTA  Plug-in Hybrid Electric Vehicle (PHEV)
# 130437  WBA13AG06M     BMW  Plug-in Hybrid Electric Vehicle (PHEV)
#
# [16446 rows x 3 columns]

# %%
#Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
df_tesla=df[["Make","Model Year","Model"]][df["City"] == "Bothell"]

# %%
df_tesla[df_tesla["Make"]=="TESLA"]
# Out:
#          Make  Model Year    Model
# 39      TESLA        2020  MODEL 3
# 217     TESLA        2022  MODEL 3
# 218     TESLA        2022  MODEL Y
# 222     TESLA        2018  MODEL 3
# 292     TESLA        2017  MODEL X
# ...       ...         ...      ...
# 129778  TESLA        2019  MODEL 3
# 129954  TESLA        2021  MODEL 3
# 129976  TESLA        2014  MODEL S
# 130295  TESLA        2022  MODEL 3
# 130392  TESLA        2018  MODEL 3
#
# [2407 rows x 3 columns]

# %%
#Get all the cars that have an electric range of more than 100, and were made after2015

# %%
df_range = df[df["Electric Range"] > 100]

# %%
df_range[df_range["Model Year"] > 2017]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# 20      5YJ3E1EA9L  Thurston          Lacey    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
#Draw plots to show the distribution between city and electric vehicle type

# %%
import seaborn as sns

# %%
g = sns.scatterplot(df["City"],df["Electric Vehicle Type"],size=200)
g.set_xticklabels(df["City"],rotation=90)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\shash\AppData\Local\Temp\ipykernel_6164\2026203560.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(df["City"],rotation=90)
# [Text(0, 0, 'Yakima'),
#  Text(1, 0, 'Poulsbo'),
#  Text(2, 0, 'Seattle'),
#  Text(3, 0, 'Seattle'),
#  Text(4, 0, 'Lacey'),
#  Text(5, 0, 'Olympia'),
#  Text(6, 0, 'Tumwater'),
#  Text(7, 0, 'Lacey'),
#  Text(8, 0, 'Rochester'),
#  Text(9, 0, 'Bremerton'),
#  Text(10, 0, 'Lacey'),
#  Text(11, 0, 'Yakima'),
#  Text(12, 0, 'Lacey'),
#  Text(13, 0, 'Olympia'),
#  Text(14, 0, 'Lacey'),
#  Text(15, 0, 'Bainbridge Island'),
#  Text(16, 0, 'Yakima'),
#  Text(17, 0, 'Olympia'),
# ...
